# %%
- Lecture: Security Hardening Fundamentals
    - What is at risk?
        - DATA
    - Basic Principles:
        - Principle of Least Privilege
        - Defense in Depth
        - Keep It Simple
        - Compartmentalization (Don't everything in one place.)
                                OS called cuebe for compartmentalization
    - Basic Password Security
        - Password length
            - 4 chars: 456,976 combinations
            - 5 chars: 11.8M
            - 6 chars: 308.9M
            - 7 chars: 8B
            - 8 chars: 200B
            - 9 chars: 5.4T
            - 10 chars: 141T
            - 12 chars: 95Q
        - Password complexity
            - Does it work? (Brute force will trigger alarm)
            - Analyze behavior and factor
        - Password rotaiton
            - Does it work?
        - Password reuse
            - Does it work?
        - Recommend passphrases & 12 character min
        - Password manager
            - Install LastPass
        - Multi-factor Auth
            - Something you know
            - Something you have
            - Something you are
    - Disable guest accounts
    - Secure Patches and Automatic Updates
        - Windows Updates
        - Ubuntu unattended-upgrades
        - Security Patch Notifications
            - Sign up for notifications for our servers
            - WE WILL BE NEEDING TO PROTECT THESE SERVERS AT ALL TIMES
        - Shared accounts and account maintenance
            - Lab: Generate an employee onboarding/exit document
    - Encryption
        - Encrypt everything
        - Disk Encryption
        - BIOS Passwords
    - Admin Workstation Hardening
        - Lock Screen
            - Always lock when you leave
            - Locking Shortcuts
            - Enable on suspend/hibernation/awake
    -Basic Browser Security
        - HTTPS Everywhere
        - Adblock Plus
        - Privacy Badger (block tracker at you by default) privacy badger chrome plugin 
                                electronic frontier foundation
        - NoScript (optional) does not allow javascript run a page...alter your browsing experience.
                                TOR  noscript chrom plugin
    - Windows Anti-Virus
                                
-Lecture: Set up SSH and sudo
    - sudo advantages
        - `/etc/sudoers`
         sudo usermod -aG sudo tyler
        - no shared passwords
        - easy to remove users from privileged roles
        - sudo provides an audit trail
            - show example in `/var/log/auth.log`
        - edit with visudo `/etc/sudoers`
            - validation editor
        - grant access to groups, not users
            - can restrict access to specific executables
                - `%dbs ALL=(postgres) (/usr/bin/psql`
            - can restrict acess to custom scripts
                - `bob ALL=(root) /usr/local/bin/restart_nginx`
        - Try not to use NOPASSWD
    - `/etc/ssh/sshi
          ~/.ssh/id_rsa.pub  
            encrypt your message with private key
            you sent your message with public key
          .ssh/id.
                                    
            create ssh folders in root directory
                must install ssh onto your machines
                sudo service ssh status
                ssh jaywon@10.0.1.123
                                        
                sudo vim /etc/ssh/sshd_config
                                        
                                        
                ssh-copy-id jaywon@10.0.1.123 or ssh-copy-id 10.0.1.123 if userid is the same
                                        
                /usr/lib
                /usr/local/lib
                /usr/local/bin
                man hier - file system hierarchy
    
    ip addr
    ifconfig
                                        
    [myong@oracle12c ~]$ sudo useradd -G wheel -c "Mary Yong" myong
    useradd: user 'myong' already exists

                            
    [myong@oracle12c ~]$ sudo systemctl start sshd.service
    [myong@oracle12c ~]$ sudo systemctl restart sshd.service
    [myong@oracle12c ~]$ service sshd status
    Redirecting to /bin/systemctl status  sshd.service
    ● sshd.service - OpenSSH server daemon
       Loaded: loaded (/usr/lib/systemd/system/sshd.service; enabled; vendor preset: enabled)
       Active: active (running) since Tue 2017-12-05 02:54:36 EST; 22s ago
         Docs: man:sshd(8)
               man:sshd_config(5)
     Main PID: 5561 (sshd)
       CGroup: /system.slice/sshd.service
               └─5561 /usr/sbin/sshd -D

    Dec 05 02:54:36 oracle12c systemd[1]: Started OpenSSH server daemon.
    Dec 05 02:54:36 oracle12c systemd[1]: Starting OpenSSH server daemon...
    Dec 05 02:54:37 oracle12c sshd[5561]: Server listening on 0.0.0.0 port 22.
    Dec 05 02:54:37 oracle12c sshd[5561]: Server listening on :: port 22.
    [myong@oracle12c ~]$ ssh myong@10.0.2.25
    ssh: connect to host 10.0.2.25 port 22: No route to host
    [myong@oracle12c ~]$ ssh myong@10.0.2.15
    myong@10.0.2.15's password: 
    Last login: Tue Dec  5 02:45:25 2017 from 10.0.2.15
                                        
    sudo apt-get install openssh-server
    ifconfig
    
Alysa - Networking:
    - 11 types of Network
        - VLAN - Virtual Local Area Network. All devices hook up to a switch.
            - logically assigning where connections are going based on the port.
            - Improved security;
            - Reduced cost
            - Better performance
            - Smaller Broadcast Domains
            - IT Efficiency
        - VPN - Using WAN link connect to local remote area network.  ssh..NORDVPN
        - WLAN - Wireless Local area network 
            - wireless connects in small geographic environment.  
              There is access point thruout campus connect to it. High frequency radiowave.
            - Extend a signal.  
        - VSAN - Virtual SAN
        - SAN - Storage area network (high-speed network; applicatio on network servers, vmware offer SAN)
        - WAN - Wide area network (span city, state, country; runs at slower speed. ie internet)
        - MAN - Metropolitan area network (span across city; telecom, internet access; service thru city)
        - CAN - Campus area network (campus area network)
        - LAN - local area network (home, small business, local geographical area)
        - PAN - Personal Area Network (Me, computer, wireless...home network)
                                        
    Topologies:
        - Bus - One main cable; flat representation;  
        - STAR - P2P connection; not scalable; network connection may be slow;
            - main central switch in the middle (HUB)
        - ring - connected via a circular loop...closed loop form of networking
            - good for speed; can overload the system.
            - each device must be functioning in order for the system to work.
            - use a token and circulate entire network.
            - doesn't internet
        - mesh - every node is connected to every other node in the network.
            - good for redundancy; troubleshooting; security;
            - listening for traffic; client server
        - Peer to Peer (P2P) or more PCs that are connected together sharing resources w/o going separater server
        - Client/Server -client communicate with server.  Server in control. 
    Hybrid topologies
        Connection: 
            Hubs are dumps
            switches
        coax-connect to TV
        Straight Thru Wiring Guide (568B)-use all the time - printer to router
        Crossover Wiring Tuide (568B)- connect switch to switch or router to router
        physical and fiber optic - security related to wire...snoop data transfer..
        fiber optic ....can't snoop data transfer....
        switch - creates a network ...layer 2 of OSI model...use MAC addresses
        router - connects a network
        router layer 3 of OSI model...layer 3 switch...IP addresses
                                        
        serial cable....
                                        
        OSI Model  --- 
        7. Application   --FTP, TFTP, HTTP SMTP, DNS, TELNET, SNMP
        6. Presentation  -- Very little focus
        5. Session
        4. Transport --- TCP (the Internet)
        3. Network   --- IP (the internet)  Router
        2. Data Link -- Ethernet  Switch
        1. Physical
                                        
        All people seem to need data processing.
